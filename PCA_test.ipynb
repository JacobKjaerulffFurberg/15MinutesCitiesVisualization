# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(1000, 2), columns=list('AB'))

# %%
df.head()
# Out:
#           A         B
# 0  0.644148  0.870113
# 1  0.514616  0.220358
# 2  0.540566  0.761574
# 3  0.733843  0.856203
# 4  0.705860  0.889620

# %%
eig_vals
# Out:
# array([0.07781185, 0.09565418])

# %%
eig_vals, eig_vecs = np.linalg.eig(np.cov(df.T))

# %%
eig_vals[1] / sum(eig_vals)
# Out:
# 0.49572294611556894

# %%
projected_X = df.dot(eig_vecs.T[1])
projected_X
# Out:
# 0      0.241966
# 1     -0.167330
# 2      0.226892
# 3      0.173062
# 4      0.216646
#          ...
# 995   -0.267904
# 996    0.294378
# 997    0.408610
# 998   -0.605967
# 999    0.147250
# Length: 1000, dtype: float64

# %%
df['y_axis'] = 0.0
df['PCA'] = projected_X
df.head()
# Out:
#           A         B  y_axis       PCA
# 0  0.644148  0.870113     0.0  0.241966
# 1  0.514616  0.220358     0.0 -0.167330
# 2  0.540566  0.761574     0.0  0.226892
# 3  0.733843  0.856203     0.0  0.173062
# 4  0.705860  0.889620     0.0  0.216646

# %%
df
# Out:
#             A         B  y_axis       PCA
# 0    0.644148  0.870113     0.0  0.241966
# 1    0.514616  0.220358     0.0 -0.167330
# 2    0.540566  0.761574     0.0  0.226892
# 3    0.733843  0.856203     0.0  0.173062
# 4    0.705860  0.889620     0.0  0.216646
# ..        ...       ...     ...       ...
# 995  0.676575  0.226631     0.0 -0.267904
# 996  0.678877  0.968851     0.0  0.294378
# 997  0.041908  0.573822     0.0  0.408610
# 998  0.964110  0.027775     0.0 -0.605967
# 999  0.641020  0.742740     0.0  0.147250
#
# [1000 rows x 4 columns]

# %%
import seaborn as sns

sns.lmplot('A', 'B', data=df)
# Out:
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.lmplot('PCA', 'y_axis', data=df)
# Out:
# /opt/homebrew/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
import plotly.express as px

# %%
px.scatter(df, 'A', 'B', 'PCA')
